# %%
# from the NS results, build and analyze the dependency graph of each domain.
# INPUT:
#   folder_analysis (global variable, folder for analysis)
# OUTPUT:
#   folder_analysis/Graph/ (optional, controlled by SAVE_GRAPH_AS_FILE)
#   folder_analysis/graph_set_per_domain.bin
#   folder_analysis/graph_set_global.bin
# Python 3

import sys
import os
import time
import networkx as nx
import matplotlib.pyplot as plt
import pickle

###### FUNC ######
# DFS of the dependency graph of each domain. 1. from NS record; 2. from the direct parent domain.
# mode is one of the following: "general", "explicit", "critical", "essential"
# build global graphs WHILE building individual ones.


## 去除自环
def wipecycle(G):
    remove_edges = []
    for u,v in G.edges():
        if u == v:
            remove_edges.append((u,v))
    for i in remove_edges:
        G.remove_edge(i[0], i[1])

def build_graph(domain, G, mode):
    # 1. find the next node from NS records.
    try:
        for ns in domain_ns[domain]:
            # only take the parent of each NS.
            ns_parent = ns[ns.find(".") + 1:]
            if mode == "general":
                # [General] add everything.
                # if ns is already in the graph (i.e., visited), then just add the edge.
                if ns_parent not in G.nodes:
                    G.add_node(ns_parent)
                    G.add_edge(domain, ns_parent)
                    # add the node and edge to GLOBAL graph.
                    if ns_parent not in Global_graph_set[mode].nodes:
                        Global_graph_set[mode].add_node(ns_parent)
                    if not Global_graph_set[mode].has_edge(domain, ns_parent):
                        Global_graph_set[mode].add_edge(domain, ns_parent)
                    build_graph(ns_parent, G, mode)
                else:
                    G.add_edge(domain, ns_parent)
                    # add the edge to GLOBAL graph.
                    if not Global_graph_set[mode].has_edge(domain, ns_parent):
                        Global_graph_set[mode].add_edge(domain, ns_parent)
            elif mode == "explicit" and not has_glue(domain, ns):
                # [Explicit] only add nodes without glue.
                if ns_parent not in G.nodes:
                    G.add_node(ns_parent)
                    G.add_edge(domain, ns_parent)
                    # add the node and edge to GLOBAL graph.
                    if ns_parent not in Global_graph_set[mode].nodes:
                        Global_graph_set[mode].add_node(ns_parent)
                    if not Global_graph_set[mode].has_edge(domain, ns_parent):
                        Global_graph_set[mode].add_edge(domain, ns_parent)
                    build_graph(ns_parent, G, mode)
                else:
                    G.add_edge(domain, ns_parent)
                    # add the edge to GLOBAL graph.
                    if not Global_graph_set[mode].has_edge(domain, ns_parent):
                        Global_graph_set[mode].add_edge(domain, ns_parent)
            elif mode == "critical":
                # [Critical] only add nodes if EVERY NS is without glue.
                glue_flag = False
                for ns in domain_ns[domain]:
                    if has_glue(domain, ns):
                        glue_flag = True
                        break
                if not glue_flag:
                    if ns_parent not in G.nodes:
                        G.add_node(ns_parent)
                        G.add_edge(domain, ns_parent)
                        # add the node and edge to GLOBAL graph.
                        if ns_parent not in Global_graph_set[mode].nodes:
                            Global_graph_set[mode].add_node(ns_parent)
                        if not Global_graph_set[mode].has_edge(domain, ns_parent):
                            Global_graph_set[mode].add_edge(domain, ns_parent)
                        build_graph(ns_parent, G, mode)
                    else:
                        G.add_edge(domain, ns_parent)
                        # add the edge to GLOBAL graph.
                        if not Global_graph_set[mode].has_edge(domain, ns_parent):
                            Global_graph_set[mode].add_edge(domain, ns_parent)
            # [Essential] do nothing.
    except Exception as e:
        print("[ns error]", domain, e)

    # 2. find the next node from the direct parent.
    # the parent node applies to all modes.
    if domain.find(".") >= 0:
        parent = domain[domain.find(".") + 1:]
    else:
        parent = "."
    if parent not in G.nodes:
        G.add_node(parent)
        G.add_edge(domain, parent)
        # add the node and edge to GLOBAL graph.
        if parent not in Global_graph_set[mode].nodes:
            Global_graph_set[mode].add_node(parent)
        if not Global_graph_set[mode].has_edge(domain, parent):
            Global_graph_set[mode].add_edge(domain, parent)
        # root does not need searching.
        if parent != ".":
            build_graph(parent, G, mode)
    else:
        G.add_edge(domain, parent)
        # add the edge to GLOBAL graph.
        if not Global_graph_set[mode].has_edge(domain, parent):
            Global_graph_set[mode].add_edge(domain, parent)


# record: dom1 NS dom2.
# determining if there is a glue of dom2 in the parent of dom1.
def has_glue(dom1, dom2):
    # dom1: example.com; dom2: ns2.example.net
    # get parent of dom2 and dom1.
    parent_of_dom2 = dom2[dom2.find(".") + 1:]  # example.net
    if dom1.find(".") < 0:
        # the parent of dom1 is root. return true because everything is under root.
        return True
    parent_of_dom1 = dom1[dom1.find(".") + 1:]  # com

    # if parent of dom2 is not under parent of dom1, then it is out-of-bailiwick (no glue).
    if not parent_of_dom2.endswith("." + parent_of_dom1):
        return False
    else:
        return True

# %%
###### GLOBAL CONFIG ######
folder_analysis = "res"

DEBUG = True

#生成图之前是否去掉自环
wc = True

tars = ['edu', 'gov', 'other']

for tar in tars:
    domain_file = "../data/"+tar+".list"
    ntype = tar
    ns_file = "../data/"+ntype+".domain_ns_info.txt"
    null_ns = "~NO~NS~"

    SAVE_GRAPH_AS_FILE = False
    graph_output_dir = "../data/graph/"

    # for each domain
    Graph_set = {}
    # global graphs. Global_graph_set = {"general": G, "explicit", "critical", "essential"}
    Global_graph_set = {}
    for mode in ["essential", "general", "explicit", "critical"]:
        Global_graph_set[mode] = nx.DiGraph()

    domain_list = []
    inputf = open(domain_file)
    for line in inputf:
        domain_list.append(line.strip().lower().split("\t")[0])
    inputf.close()
    print("[++] Domains in list:", len(domain_list))

    # read and store (domain, ns) mappings from ns_file. domain_ns[domain] = {ns1, ns2, ...}
    domain_ns = {}
    inputf = open(ns_file)
    for line in inputf:
        line = line.strip()
        try:
            domain, ns = line.split("\t")
        except:
            print(line)
            continue
        ns = ns.rstrip(".")
        # if this is some true ns and not dead end, add to dict.
        if ns != null_ns:
            if domain not in domain_ns:
                domain_ns[domain] = []
            if ns not in domain_ns[domain]:
                domain_ns[domain].append(ns)
    print("[++] Zones in NS dict:", len(domain_ns))

    ###### MAIN ######
    # begin query ns of these domains.
    counter = 1
    for domain in domain_list:
        # one graph for each domain.
        G_set = {}
        # build graph for essential first, as the metrics of all graphs depend on it.
        for mode in ["essential", "general", "explicit", "critical"]:
            # build graph first.
            G_set[mode] = {}
            G_set[mode]["graph"] = nx.DiGraph()
            G_set[mode]["graph"].add_node(domain)
            print("[+++++] domain no.", counter, domain, mode)
            build_graph(domain, G_set[mode]["graph"], mode)

            # show and save graphs.
            # if SAVE_GRAPH_AS_FILE or domain == "tsinghua.edu.cn":
            #     if wc:
            #         wipecycle(G_set[mode]["graph"])
            #     nx.draw_spring(G_set[mode]["graph"], with_labels=True)
            #     plt.savefig(graph_output_dir + domain + "." + mode + ".png")
            #     plt.clf()

            # calc metrics.
            if mode != "essential":
                # Zn = V(G) - V(G_essential)
                Zn = G_set[mode]["graph"].nodes - G_set["essential"]["graph"].nodes
                # 1. ExtraSize(G) = |Zn|
                G_set[mode]["extrasize"] = len(Zn)

                # 2. AvgExtraDepth & MaxExtraDepth
                AvgExtraDepth = 0
                MaxExtraDepth = 0
                # the value does not make sense when Zn is empty.
                if len(Zn) == 0:
                    G_set[mode]["avgextradepth"] = AvgExtraDepth
                    G_set[mode]["maxextradepth"] = MaxExtraDepth
                    continue
                for zi in Zn:
                    # get the distance between domain and zi (i.e., each node in Zn).
                    depth = nx.shortest_path_length(
                        G_set[mode]["graph"], source=domain, target=zi)
                    AvgExtraDepth += depth
                    if depth > MaxExtraDepth:
                        MaxExtraDepth = depth
                AvgExtraDepth /= float(len(Zn))
                G_set[mode]["avgextradepth"] = AvgExtraDepth
                G_set[mode]["maxextradepth"] = MaxExtraDepth

        Graph_set[domain] = G_set

        counter += 1
        if DEBUG and counter > 200:
            break

    pickle.dump(Graph_set, open(domain_file[:-4]+"graph_set_per_domain.bin", "wb"))
    pickle.dump(Global_graph_set, open(domain_file[:-4]+"graph_set_global.bin", "wb"))
    
    if tar == 'edu':
        for mode in ["essential", "general", "explicit", "critical"]:
            if wc:
                wipecycle(Graph_set["tsinghua.edu.cn"][mode]["graph"])
            nx.draw_spring(Graph_set['tsinghua.edu.cn'][mode]["graph"], with_labels=True)
            plt.savefig(graph_output_dir + 'tsinghua.edu.cn' + "." + mode + ".png")
            plt.clf()
    
    for i in Global_graph_set:
        if wc:
            wipecycle(Global_graph_set[i])
        nx.draw_spring(Global_graph_set[i], with_labels=True)
        plt.savefig(graph_output_dir + ntype + "." + i + ".png")
        plt.clf()
# Out:
# [++] Domains in list: 150
# [++] Zones in NS dict: 171
# [+++++] domain no. 1 sjtu.edu.cn essential
# [+++++] domain no. 1 sjtu.edu.cn general
# [+++++] domain no. 1 sjtu.edu.cn explicit
# [+++++] domain no. 1 sjtu.edu.cn critical
# [+++++] domain no. 2 time.edu.cn essential
# [+++++] domain no. 2 time.edu.cn general
# [+++++] domain no. 2 time.edu.cn explicit
# [+++++] domain no. 2 time.edu.cn critical
# [+++++] domain no. 3 tsinghua.edu.cn essential
# [+++++] domain no. 3 tsinghua.edu.cn general
# [+++++] domain no. 3 tsinghua.edu.cn explicit
# [+++++] domain no. 3 tsinghua.edu.cn critical
# [+++++] domain no. 4 neu.edu.cn essential
# [+++++] domain no. 4 neu.edu.cn general
# [+++++] domain no. 4 neu.edu.cn explicit
# [+++++] domain no. 4 neu.edu.cn critical
# [+++++] domain no. 5 neea.edu.cn essential
# [+++++] domain no. 5 neea.edu.cn general
# [+++++] domain no. 5 neea.edu.cn explicit
# [+++++] domain no. 5 neea.edu.cn critical
# [+++++] domain no. 6 moe.edu.cn essential
# [+++++] domain no. 60 gansu.gov.cn critical
# [+++++] domain no. 61 moe.gov.cn essential
# [+++++] domain no. 61 moe.gov.cn general
# [+++++] domain no. 61 moe.gov.cn explicit
# [+++++] domain no. 61 moe.gov.cn critical
# [+++++] domain no. 62 nhsa.gov.cn essential
# [+++++] domain no. 62 nhsa.gov.cn general
# [+++++] domain no. 62 nhsa.gov.cn explicit
# [+++++] domain no. 62 nhsa.gov.cn critical
# [+++++] domain no. 63 csrc.gov.cn essential
# [+++++] domain no. 63 csrc.gov.cn general
# [+++++] domain no. 63 csrc.gov.cn explicit
# [+++++] domain no. 63 csrc.gov.cn critical
# [+++++] domain no. 64 fy.gov.cn essential
# [+++++] domain no. 64 fy.gov.cn general
# [+++++] domain no. 64 fy.gov.cn explicit
# [+++++] domain no. 64 fy.gov.cn critical
# [+++++] domain no. 65 fmprc.gov.cn essential
# [+++++] domain no. 65 fmprc.gov.cn general
# [+++++] domain no. 65 fmprc.gov.cn explicit
# [+++++] domain no. 65 fmprc.gov.cn critical
# [+++++] domain no. 66 ccdi.gov.cn essential
# [+++++] domain no. 66 ccdi.gov.cn general
# [+++++] domain no. 66 ccdi.gov.cn explicit
# [+++++] domain no. 66 ccdi.gov.cn critical
# [+++++] domain no. 67 fuzhou.gov.cn essential
# [+++++] domain no. 67 fuzhou.gov.cn general
# [+++++] domain no. 67 fuzhou.gov.cn explicit
# [+++++] domain no. 67 fuzhou.gov.cn critical
# [+++++] domain no. 68 pbc.gov.cn essential
# [+++++] domain no. 68 pbc.gov.cn general
# [+++++] domain no. 68 pbc.gov.cn explicit
# [+++++] domain no. 68 pbc.gov.cn critical
# [+++++] domain no. 69 mee.gov.cn essential
# [+++++] domain no. 69 mee.gov.cn general
# [+++++] domain no. 69 mee.gov.cn explicit
# [+++++] domain no. 69 mee.gov.cn critical
# [+++++] domain no. 70 nmg.gov.cn essential
# [+++++] domain no. 70 nmg.gov.cn general
# [+++++] domain no. 70 nmg.gov.cn explicit
# [+++++] domain no. 70 nmg.gov.cn critical
# [+++++] domain no. 71 mnr.gov.cn essential
# [+++++] domain no. 71 mnr.gov.cn general
# [ns error] win-b3a7gll8hv8 'win-b3a7gll8hv8'
# [+++++] domain no. 71 mnr.gov.cn explicit
# [ns error] win-b3a7gll8hv8 'win-b3a7gll8hv8'
# [+++++] domain no. 71 mnr.gov.cn critical
# [ns error] win-b3a7gll8hv8 'win-b3a7gll8hv8'
# [+++++] domain no. 72 qxqf.gov.cn essential
# [+++++] domain no. 72 qxqf.gov.cn general
# [+++++] domain no. 72 qxqf.gov.cn explicit
# [+++++] domain no. 72 qxqf.gov.cn critical
# [+++++] domain no. 73 dg.gov.cn essential
# [+++++] domain no. 73 dg.gov.cn general
# [+++++] domain no. 73 dg.gov.cn explicit
# [+++++] domain no. 73 dg.gov.cn critical
# [+++++] domain no. 74 nhc.gov.cn essential
# [+++++] domain no. 74 nhc.gov.cn general
# [+++++] domain no. 74 nhc.gov.cn explicit
# [+++++] domain no. 74 nhc.gov.cn critical
# [ns error] authdns.ripe.net 'authdns.ripe.net'
# [ns error] sth.netnod.se 'sth.netnod.se'
# [ns error] ns.se 'ns.se'
# [ns error] anycast.pch.net 'anycast.pch.net'
# [ns error] dns.tw 'dns.tw'
# [+++++] domain no. 127 mediatek.com explicit
# [+++++] domain no. 127 mediatek.com critical
# [+++++] domain no. 128 clickwifi.net essential
# [+++++] domain no. 128 clickwifi.net general
# [+++++] domain no. 128 clickwifi.net explicit
# [+++++] domain no. 128 clickwifi.net critical
# [+++++] domain no. 129 ks-live.com essential
# [+++++] domain no. 129 ks-live.com general
# [ns error] a.ksycdn.cn 'a.ksycdn.cn'
# [+++++] domain no. 129 ks-live.com explicit
# [+++++] domain no. 129 ks-live.com critical
# [+++++] domain no. 130 jpush.cn essential
# [+++++] domain no. 130 jpush.cn general
# [+++++] domain no. 130 jpush.cn explicit
# [+++++] domain no. 130 jpush.cn critical
# [+++++] domain no. 131 xycdn.com essential
# [+++++] domain no. 131 xycdn.com general
# [+++++] domain no. 131 xycdn.com explicit
# [+++++] domain no. 131 xycdn.com critical
# [+++++] domain no. 132 pgzs.com essential
# [+++++] domain no. 132 pgzs.com general
# [+++++] domain no. 132 pgzs.com explicit
# [+++++] domain no. 132 pgzs.com critical
# [+++++] domain no. 133 tanx.com essential
# [+++++] domain no. 133 tanx.com general
# [+++++] domain no. 133 tanx.com explicit
# [+++++] domain no. 133 tanx.com critical
# [+++++] domain no. 134 nearme.com.cn essential
# [+++++] domain no. 134 nearme.com.cn general
# [+++++] domain no. 134 nearme.com.cn explicit
# [+++++] domain no. 134 nearme.com.cn critical
# [+++++] domain no. 135 chinamobile.com essential
# [+++++] domain no. 135 chinamobile.com general
# [+++++] domain no. 135 chinamobile.com explicit
# [+++++] domain no. 135 chinamobile.com critical
# [+++++] domain no. 136 bytemastatic.com essential
# [+++++] domain no. 136 bytemastatic.com general
# [+++++] domain no. 136 bytemastatic.com explicit
# [+++++] domain no. 136 bytemastatic.com critical
# [+++++] domain no. 137 servicewechat.com essential
# [ns error] servicewechat.com 'servicewechat.com'
# [+++++] domain no. 137 servicewechat.com general
# [ns error] servicewechat.com 'servicewechat.com'
# [+++++] domain no. 137 servicewechat.com explicit
# [ns error] servicewechat.com 'servicewechat.com'
# [+++++] domain no. 137 servicewechat.com critical
# [ns error] servicewechat.com 'servicewechat.com'
# [+++++] domain no. 138 kugou.com essential
# [+++++] domain no. 138 kugou.com general
# [+++++] domain no. 138 kugou.com explicit
# [+++++] domain no. 138 kugou.com critical
# [+++++] domain no. 139 gstatic.com essential
# [+++++] domain no. 139 gstatic.com general
# [+++++] domain no. 139 gstatic.com explicit
# [+++++] domain no. 139 gstatic.com critical
# [+++++] domain no. 140 ucweb.com essential
# [+++++] domain no. 140 ucweb.com general
# [+++++] domain no. 140 ucweb.com explicit
# [+++++] domain no. 140 ucweb.com critical
# [+++++] domain no. 141 cnzz.com essential
# [+++++] domain no. 141 cnzz.com general
# [+++++] domain no. 141 cnzz.com explicit
# [+++++] domain no. 141 cnzz.com critical
# [+++++] domain no. 142 dbankcloud.com essential
# [+++++] domain no. 142 dbankcloud.com general
# [+++++] domain no. 142 dbankcloud.com explicit
# [+++++] domain no. 142 dbankcloud.com critical
# [+++++] domain no. 143 weibo.com essential
# [+++++] domain no. 143 weibo.com general
# [+++++] domain no. 143 weibo.com explicit
# [+++++] domain no. 143 weibo.com critical
# [+++++] domain no. 144 alibaba.com essential
# [+++++] domain no. 144 alibaba.com general
# [+++++] domain no. 144 alibaba.com explicit
# [+++++] domain no. 144 alibaba.com critical
# [+++++] domain no. 145 clientservices.googleapis.com essential
# [ns error] clientservices.googleapis.com 'clientservices.googleapis.com'
# [+++++] domain no. 145 clientservices.googleapis.com general
# [ns error] clientservices.googleapis.com 'clientservices.googleapis.com'
# [+++++] domain no. 145 clientservices.googleapis.com explicit
# [ns error] clientservices.googleapis.com 'clientservices.googleapis.com'
# [+++++] domain no. 145 clientservices.googleapis.com critical
# [ns error] clientservices.googleapis.com 'clientservices.googleapis.com'
# [+++++] domain no. 146 cmpassport.com essential
# [+++++] domain no. 146 cmpassport.com general
# [+++++] domain no. 146 cmpassport.com explicit
# [+++++] domain no. 146 cmpassport.com critical
# [+++++] domain no. 147 openspeech.cn essential
# [+++++] domain no. 147 openspeech.cn general
# [+++++] domain no. 147 openspeech.cn explicit
# [+++++] domain no. 147 openspeech.cn critical
# [+++++] domain no. 148 fxltsbl.com essential
# [+++++] domain no. 148 fxltsbl.com general
# [+++++] domain no. 148 fxltsbl.com explicit
# [+++++] domain no. 148 fxltsbl.com critical
# [+++++] domain no. 149 www.googleapis.com essential
# [ns error] www.googleapis.com 'www.googleapis.com'
# [+++++] domain no. 149 www.googleapis.com general
# [ns error] www.googleapis.com 'www.googleapis.com'
# [+++++] domain no. 149 www.googleapis.com explicit
# [ns error] www.googleapis.com 'www.googleapis.com'
# [+++++] domain no. 149 www.googleapis.com critical
# [ns error] www.googleapis.com 'www.googleapis.com'
# [+++++] domain no. 150 360buyimg.com essential
# [+++++] domain no. 150 360buyimg.com general
# [+++++] domain no. 150 360buyimg.com explicit
# [+++++] domain no. 150 360buyimg.com critical
# [+++++] domain no. 151 tmall.com essential
# [+++++] domain no. 151 tmall.com general
# [+++++] domain no. 151 tmall.com explicit
# [+++++] domain no. 151 tmall.com critical
# [+++++] domain no. 152 bytescm.com essential
# [+++++] domain no. 152 bytescm.com general
# [+++++] domain no. 152 bytescm.com explicit
# [+++++] domain no. 152 bytescm.com critical
# [+++++] domain no. 153 bsgslb.cn essential
# [+++++] domain no. 153 bsgslb.cn general
# [+++++] domain no. 153 bsgslb.cn explicit
# [+++++] domain no. 153 bsgslb.cn critical
# [+++++] domain no. 154 mob.com essential
# [+++++] domain no. 154 mob.com general
# [+++++] domain no. 154 mob.com explicit
# [+++++] domain no. 154 mob.com critical
# [+++++] domain no. 155 douyin.com essential
# [+++++] domain no. 155 douyin.com general
# [+++++] domain no. 155 douyin.com explicit
# [+++++] domain no. 155 douyin.com critical
# [+++++] domain no. 156 alibabachengdun.com essential
# [+++++] domain no. 156 alibabachengdun.com general
# [+++++] domain no. 156 alibabachengdun.com explicit
# [+++++] domain no. 156 alibabachengdun.com critical
# [+++++] domain no. 157 ibytedapm.com essential
# [+++++] domain no. 157 ibytedapm.com general
# [+++++] domain no. 157 ibytedapm.com explicit
# [+++++] domain no. 157 ibytedapm.com critical
# [+++++] domain no. 158 gvt2.com essential
# [+++++] domain no. 158 gvt2.com general
# [+++++] domain no. 158 gvt2.com explicit
# [+++++] domain no. 158 gvt2.com critical
# [+++++] domain no. 159 finzfin.com essential
# [+++++] domain no. 159 finzfin.com general
# [+++++] domain no. 159 finzfin.com explicit
# [+++++] domain no. 159 finzfin.com critical
# [+++++] domain no. 160 bytegoofy.com essential
# [+++++] domain no. 160 bytegoofy.com general
# [+++++] domain no. 160 bytegoofy.com explicit
# [+++++] domain no. 160 bytegoofy.com critical
# [+++++] domain no. 161 getui.net essential
# [+++++] domain no. 161 getui.net general
# [+++++] domain no. 161 getui.net explicit
# [+++++] domain no. 161 getui.net critical
# [+++++] domain no. 162 mi-img.com essential
# [+++++] domain no. 162 mi-img.com general
# [+++++] domain no. 162 mi-img.com explicit
# [+++++] domain no. 162 mi-img.com critical
# [+++++] domain no. 163 wechatpay.cn essential
# [ns error] wechatpay.cn 'wechatpay.cn'
# [+++++] domain no. 163 wechatpay.cn general
# [ns error] wechatpay.cn 'wechatpay.cn'
# [+++++] domain no. 163 wechatpay.cn explicit
# [ns error] wechatpay.cn 'wechatpay.cn'
# [+++++] domain no. 163 wechatpay.cn critical
# [ns error] wechatpay.cn 'wechatpay.cn'
# [+++++] domain no. 164 url.cn essential
# [+++++] domain no. 164 url.cn general
# [+++++] domain no. 164 url.cn explicit
# [+++++] domain no. 164 url.cn critical
# [+++++] domain no. 165 dutils.com essential
# [+++++] domain no. 165 dutils.com general
# [+++++] domain no. 165 dutils.com explicit
# [+++++] domain no. 165 dutils.com critical
# [+++++] domain no. 166 gepush.com essential
# [+++++] domain no. 166 gepush.com general
# [+++++] domain no. 166 gepush.com explicit
# [+++++] domain no. 166 gepush.com critical
# [+++++] domain no. 167 windows.com essential
# [+++++] domain no. 167 windows.com general
# [+++++] domain no. 167 windows.com explicit
# [+++++] domain no. 167 windows.com critical
# [+++++] domain no. 168 wps.cn essential
# [+++++] domain no. 168 wps.cn general
# [+++++] domain no. 168 wps.cn explicit
# [+++++] domain no. 168 wps.cn critical
# [+++++] domain no. 169 qy.net essential
# [+++++] domain no. 169 qy.net general
# [+++++] domain no. 169 qy.net explicit
# [+++++] domain no. 169 qy.net critical
# [+++++] domain no. 170 ksc-test.com essential
# [+++++] domain no. 170 ksc-test.com general
# [+++++] domain no. 170 ksc-test.com explicit
# [+++++] domain no. 170 ksc-test.com critical
# [+++++] domain no. 171 126.net essential
# [+++++] domain no. 171 126.net general
# [+++++] domain no. 171 126.net explicit
# [+++++] domain no. 171 126.net critical
# [+++++] domain no. 172 netease.com essential
# [+++++] domain no. 172 netease.com general
# [+++++] domain no. 172 netease.com explicit
# [+++++] domain no. 172 netease.com critical
# [+++++] domain no. 173 toutiaoimg.com essential
# [+++++] domain no. 173 toutiaoimg.com general
# [+++++] domain no. 173 toutiaoimg.com explicit
# [+++++] domain no. 173 toutiaoimg.com critical
# [+++++] domain no. 174 dianping.com essential
# [+++++] domain no. 174 dianping.com general
# [+++++] domain no. 174 dianping.com explicit
# [+++++] domain no. 174 dianping.com critical
# [+++++] domain no. 175 tenpay.com essential
# [+++++] domain no. 175 tenpay.com general
# [+++++] domain no. 175 tenpay.com explicit
# [+++++] domain no. 175 tenpay.com critical
# [+++++] domain no. 176 dbankcloud.asia essential
# [+++++] domain no. 176 dbankcloud.asia general
# [+++++] domain no. 176 dbankcloud.asia explicit
# [+++++] domain no. 176 dbankcloud.asia critical
# [+++++] domain no. 177 huawei.com essential
# [+++++] domain no. 177 huawei.com general
# [+++++] domain no. 177 huawei.com explicit
# [+++++] domain no. 177 huawei.com critical
# [+++++] domain no. 178 tencentmusic.com essential
# [ns error] tencentmusic.com 'tencentmusic.com'
# [+++++] domain no. 178 tencentmusic.com general
# [ns error] tencentmusic.com 'tencentmusic.com'
# [+++++] domain no. 178 tencentmusic.com explicit
# [ns error] tencentmusic.com 'tencentmusic.com'
# [+++++] domain no. 178 tencentmusic.com critical
# [ns error] tencentmusic.com 'tencentmusic.com'
# [+++++] domain no. 179 ifeng.com essential
# [+++++] domain no. 179 ifeng.com general
# [+++++] domain no. 179 ifeng.com explicit
# [+++++] domain no. 179 ifeng.com critical
# [+++++] domain no. 180 bilibili.com essential
# [+++++] domain no. 180 bilibili.com general
# [+++++] domain no. 180 bilibili.com explicit
# [+++++] domain no. 180 bilibili.com critical
# [+++++] domain no. 181 51y5.net essential
# [+++++] domain no. 181 51y5.net general
# [+++++] domain no. 181 51y5.net explicit
# [+++++] domain no. 181 51y5.net critical
# [+++++] domain no. 182 ugdtimg.com essential
# [ns error] ugdtimg.com 'ugdtimg.com'
# [+++++] domain no. 182 ugdtimg.com general
# [ns error] ugdtimg.com 'ugdtimg.com'
# [+++++] domain no. 182 ugdtimg.com explicit
# [ns error] ugdtimg.com 'ugdtimg.com'
# [+++++] domain no. 182 ugdtimg.com critical
# [ns error] ugdtimg.com 'ugdtimg.com'
# [+++++] domain no. 183 alibabausercontent.com essential
# [+++++] domain no. 183 alibabausercontent.com general
# [+++++] domain no. 183 alibabausercontent.com explicit
# [+++++] domain no. 183 alibabausercontent.com critical
# [+++++] domain no. 184 yidianzixun.com essential
# [+++++] domain no. 184 yidianzixun.com general
# [+++++] domain no. 184 yidianzixun.com explicit
# [+++++] domain no. 184 yidianzixun.com critical
# [+++++] domain no. 185 myhuaweicloud.com essential
# [+++++] domain no. 185 myhuaweicloud.com general
# [+++++] domain no. 185 myhuaweicloud.com explicit
# [+++++] domain no. 185 myhuaweicloud.com critical
# [+++++] domain no. 186 akadns.net essential
# [+++++] domain no. 186 akadns.net general
# [+++++] domain no. 186 akadns.net explicit
# [+++++] domain no. 186 akadns.net critical
# [+++++] domain no. 187 update.googleapis.com essential
# [ns error] update.googleapis.com 'update.googleapis.com'
# [+++++] domain no. 187 update.googleapis.com general
# [ns error] update.googleapis.com 'update.googleapis.com'
# [+++++] domain no. 187 update.googleapis.com explicit
# [ns error] update.googleapis.com 'update.googleapis.com'
# [+++++] domain no. 187 update.googleapis.com critical
# [ns error] update.googleapis.com 'update.googleapis.com'
# [+++++] domain no. 188 dbankcdn.cn essential
# [+++++] domain no. 188 dbankcdn.cn general
# [+++++] domain no. 188 dbankcdn.cn explicit
# [+++++] domain no. 188 dbankcdn.cn critical
# [+++++] domain no. 189 miwifi.com essential
# [+++++] domain no. 189 miwifi.com general
# [+++++] domain no. 189 miwifi.com explicit
# [+++++] domain no. 189 miwifi.com critical
# [+++++] domain no. 190 windowsupdate.com essential
# [+++++] domain no. 190 windowsupdate.com general
# [+++++] domain no. 190 windowsupdate.com explicit
# [+++++] domain no. 190 windowsupdate.com critical
# [+++++] domain no. 191 digicert.com essential
# [+++++] domain no. 191 digicert.com general
# [ns error] p03.dynect.net 'p03.dynect.net'
# [+++++] domain no. 191 digicert.com explicit
# [ns error] p03.dynect.net 'p03.dynect.net'
# [+++++] domain no. 191 digicert.com critical
# [+++++] domain no. 192 xiaohongshu.com essential
# [+++++] domain no. 192 xiaohongshu.com general
# [+++++] domain no. 192 xiaohongshu.com explicit
# [+++++] domain no. 192 xiaohongshu.com critical
# [+++++] domain no. 193 iqiyipic.com essential
# [+++++] domain no. 193 iqiyipic.com general
# [+++++] domain no. 193 iqiyipic.com explicit
# [+++++] domain no. 193 iqiyipic.com critical
# [+++++] domain no. 194 abchina.com essential
# [+++++] domain no. 194 abchina.com general
# [+++++] domain no. 194 abchina.com explicit
# [+++++] domain no. 194 abchina.com critical
# [+++++] domain no. 195 content-autofill.googleapis.com essential
# [ns error] content-autofill.googleapis.com 'content-autofill.googleapis.com'
# [+++++] domain no. 195 content-autofill.googleapis.com general
# [ns error] content-autofill.googleapis.com 'content-autofill.googleapis.com'
# [+++++] domain no. 195 content-autofill.googleapis.com explicit
# [ns error] content-autofill.googleapis.com 'content-autofill.googleapis.com'
# [+++++] domain no. 195 content-autofill.googleapis.com critical
# [ns error] content-autofill.googleapis.com 'content-autofill.googleapis.com'
# [+++++] domain no. 196 easytomessage.com essential
# [+++++] domain no. 196 easytomessage.com general
# [+++++] domain no. 196 easytomessage.com explicit
# [+++++] domain no. 196 easytomessage.com critical
# [+++++] domain no. 197 icloud.com essential
# [+++++] domain no. 197 icloud.com general
# [ns error] ns.apple.com 'ns.apple.com'
# [+++++] domain no. 197 icloud.com explicit
# [+++++] domain no. 197 icloud.com critical
# [+++++] domain no. 198 bytednsdoc.com essential
# [+++++] domain no. 198 bytednsdoc.com general
# [+++++] domain no. 198 bytednsdoc.com explicit
# [+++++] domain no. 198 bytednsdoc.com critical
# [+++++] domain no. 199 ppsimg.com essential
# [+++++] domain no. 199 ppsimg.com general
# [+++++] domain no. 199 ppsimg.com explicit
# [+++++] domain no. 199 ppsimg.com critical
# [+++++] domain no. 200 jpush.io essential
# [+++++] domain no. 200 jpush.io general
# [+++++] domain no. 200 jpush.io explicit
# [+++++] domain no. 200 jpush.io critical
